# %%
# load the model 
import os

path_to_model = '/content/drive/MyDrive/Colab Notebooks/affecnet8_epoch5_acc0.6209.pth'

os.path.exists(path_to_model)
# Out:
# True

# %%
from torch import nn
from torch.nn import functional as F
import torch
import torch.nn.init as init
from torchvision import models


class DAN(nn.Module):
    def __init__(self, num_class=7,num_head=4, pretrained=True):
        super(DAN, self).__init__()
        
        resnet = models.resnet18(pretrained)
        
        if pretrained:
            checkpoint = torch.load('./models/resnet18_msceleb.pth')
            resnet.load_state_dict(checkpoint['state_dict'],strict=True)

        self.features = nn.Sequential(*list(resnet.children())[:-2])
        self.num_head = num_head
        for i in range(num_head):
            setattr(self,"cat_head%d" %i, CrossAttentionHead())
        self.sig = nn.Sigmoid()
        self.fc = nn.Linear(512, num_class)
        self.bn = nn.BatchNorm1d(num_class)


    def forward(self, x):
        x = self.features(x)
        heads = []
        for i in range(self.num_head):
            heads.append(getattr(self,"cat_head%d" %i)(x))
        
        heads = torch.stack(heads).permute([1,0,2])
        if heads.size(1)>1:
            heads = F.log_softmax(heads,dim=1)
            
        out = self.fc(heads.sum(dim=1))
        out = self.bn(out)
   
        return out, x, heads

class CrossAttentionHead(nn.Module):
    def __init__(self):
        super().__init__()
        self.sa = SpatialAttention()
        self.ca = ChannelAttention()
        self.init_weights()


    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                init.kaiming_normal_(m.weight, mode='fan_out')
                if m.bias is not None:
                    init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                init.constant_(m.weight, 1)
                init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                init.normal_(m.weight, std=0.001)
                if m.bias is not None:
                    init.constant_(m.bias, 0)
    def forward(self, x):
        sa = self.sa(x)
        ca = self.ca(sa)

        return ca


class SpatialAttention(nn.Module):

    def __init__(self):
        super().__init__()
        self.conv1x1 = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=1),
            nn.BatchNorm2d(256),
        )
        self.conv_3x3 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3,padding=1),
            nn.BatchNorm2d(512),
        )
        self.conv_1x3 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=(1,3),padding=(0,1)),
            nn.BatchNorm2d(512),
        )
        self.conv_3x1 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=(3,1),padding=(1,0)),
            nn.BatchNorm2d(512),
        )
        self.relu = nn.ReLU()


    def forward(self, x):
        y = self.conv1x1(x)
        y = self.relu(self.conv_3x3(y) + self.conv_1x3(y) + self.conv_3x1(y))
        y = y.sum(dim=1,keepdim=True) 
        out = x*y
        
        return out 

class ChannelAttention(nn.Module):

    def __init__(self):
        super().__init__()
        self.gap = nn.AdaptiveAvgPool2d(1)
        self.attention = nn.Sequential(
            nn.Linear(512, 32),
            nn.BatchNorm1d(32),
            nn.ReLU(inplace=True),
            nn.Linear(32, 512),
            nn.Sigmoid()    
        )


    def forward(self, sa):
        sa = self.gap(sa)
        sa = sa.view(sa.size(0),-1)
        y = self.attention(sa)
        out = sa * y
        
        return out

# %%
import os
import argparse

from PIL import Image
import numpy as np
import cv2

import torch
import torch.nn.functional as nnf
from torchvision import transforms

class Model():
    def __init__(self):
        if torch.cuda.is_available():
            print('Working with the gpu')
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.data_transforms = transforms.Compose([
                                    transforms.Resize((224, 224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])
                                ])
        self.labels = ['neutral', 'happy', 'sad', 'surprise', 'fear', 'disgust', 'anger', 'contempt']

        self.model = DAN(num_head=4, num_class=8, pretrained=False)
        checkpoint = torch.load(path_to_model,
            map_location=self.device)
        self.model.load_state_dict(checkpoint['model_state_dict'], strict=True)
        self.model.to(self.device)
        self.model.eval()

        self.face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
    
    def detect(self, img0):
        img = cv2.cvtColor(np.asarray(img0),cv2.COLOR_RGB2BGR)
        faces = self.face_cascade.detectMultiScale(img)
        
        return faces

    def fer(self, path):

        img0 = Image.open(path).convert('RGB')

        faces = self.detect(img0)

        if len(faces) == 0:
            return 'null'

        ##  single face detection
        x, y, w, h = faces[0]

        img = img0.crop((x,y, x+w, y+h))

        img = self.data_transforms(img)
        img = img.view(1,3,224,224)
        img = img.to(self.device)

        with torch.set_grad_enabled(False):
            out, _, _ = self.model(img)
            
            softmax_probs = nnf.softmax(out, dim=1)
            
            _, pred = torch.max(out,1)
            
            index = int(pred)
            label = self.labels[index]

            return label, dict(zip(self.labels, 
                                   list(np.round(i, 4) for i in softmax_probs.tolist())[0]))

# %%
class Color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %% [markdown]
# ### Test it by providing a URL

# %%
# enter an image URL
import time

img_url = input('URL:').strip()
salt = int(time.time())
# Out:
# URL:https://miro.medium.com/max/1400/1*vnewG2OYRUij_b_zm5uNrQ.png

# %%
from IPython.display import Image as image

image(url=img_url, width=400, height=256)
# Out:
# <img src="https://miro.medium.com/max/1400/1*vnewG2OYRUij_b_zm5uNrQ.png" width="400" height="256"/>

# %%
# download the image
# !wget -q -4 $img_url -O pic${salt}.png

# %%
model = Model()

#image = f"/content/sample_data/pic{str(salt)[1:]}.jpg"

image = "image.jpg"

assert os.path.exists(image), "Failed to load image file."

print(image)
label, probs = model.fer(image)
print(f'Emotion label: {label}')
print("=" * 20)
print(f'Softmax probabilities', end='\n\n')
probs
# Out:
# image.jpg
# Emotion label: neutral
# ====================
# Softmax probabilities
# {'anger': 0.0585,
#  'contempt': 0.1081,
#  'disgust': 0.0499,
#  'fear': 0.0819,
#  'happy': 0.0982,
#  'neutral': 0.3766,
#  'sad': 0.1175,
#  'surprise': 0.1092}

# %%
s = sum(probs[i] for i in ('anger', 'disgust', 'fear', 'happy', 'sad'))
[probs[i]/s for i in ('anger', 'disgust', 'fear', 'happy', 'sad')]
# Out:
# [0.14408866995073893,
#  0.12290640394088671,
#  0.2017241379310345,
#  0.24187192118226603,
#  0.2894088669950739]

# %% [markdown]
# ### Predict on all frames/images in a folder

# %%
# download the image
img_url = r"https://i1.prth.gr/images/w880/_webp/files/2022-05-25/geetha__1_.jpg"
# !wget -q -4 $img_url -O /content/Images/pic${int(time.time())}.jpg

# %%
folder_name = r'/content/drive/MyDrive/Colab Notebooks/Images_bordered/bordered_crazy_good/bordered_crazy_good'
last_part = os.path.basename(os.path.normpath(folder_name))+"_"

base = os.path.abspath(os.path.join(os.path.curdir, folder_name))
assert os.path.exists(base), 'Path doesn\'t exist'
({'path': base, 'n_images': sum(1 for _ in os.scandir(base))})
# Out:
# {'n_images': 482,
#  'path': '/content/drive/MyDrive/Colab Notebooks/Images_bordered/bordered_crazy_good/bordered_crazy_good'}

# %%
# rename files
[os.rename(os.path.join(folder_name, filename), os.path.join(folder_name,last_part+filename)) 
    for filename in os.listdir(folder_name)]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

valid_extensions = (".jpg", ".jpeg", ".png")
pics = [os.path.join(base, file_) for file_ in os.listdir(base)
            if os.path.isfile(os.path.join(base, file_)) and 
            file_.endswith(valid_extensions)]

# show images
'''
images = []
for pic in pics:
   if os.path.isfile(pic) and pic.endswith(valid_extensions): 
       images += [mpimg.imread(pic)]


plt.figure(figsize=(15,12))
plt.tight_layout()
columns = 5

for i, pic in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.axis('off')
    plt.imshow(pic, aspect='equal')
'''
# Out:
# "\nimages = []\nfor pic in pics:\n   if os.path.isfile(pic) and pic.endswith(valid_extensions): \n       images += [mpimg.imread(pic)]\n\n\nplt.figure(figsize=(15,12))\nplt.tight_layout()\ncolumns = 5\n\nfor i, pic in enumerate(images):\n    plt.subplot(len(images) / columns + 1, columns, i + 1)\n    plt.axis('off')\n    plt.imshow(pic, aspect='equal')\n"

# %%
# %%time
from collections import defaultdict
from pathlib import PurePath
import shutil 

path_to_save = os.path.abspath(r"/content/drive/MyDrive/Colab Notebooks/results/")

# store probabilities here
dic = defaultdict(list)
invalid = 0
model = Model()

for pic in pics:
    prediction = model.fer(pic)
    if prediction is 'null':
        # raise RuntimeWarning(f'No label for image {os.path.basename(pic)}')
        print(f"{Color.RED}Invalid input for {PurePath(pic).name}{Color.END}")
        invalid += 1
    else:
        label, probs = prediction
        dic[label] += [probs[label]]
        shutil.copy(os.path.join(base, PurePath(pic).name), os.path.join(path_to_save, label))
        print(f'Emotion label for {os.path.basename(pic)}: {Color.DARKCYAN}{Color.UNDERLINE}{label}{Color.END}')
        # print(f'Softmax probabilities')
        print(probs)
    print("=" * 45)

print(f"\n{Color.YELLOW}Found {invalid} invalid picture(s) out of {pics.__len__()} ({invalid / pics.__len__() * 100:.4}%){Color.END}")
# Out:
# Emotion label for bordered_crazy_good_frame_122_border.png: neutral
# {'neutral': 0.168, 'happy': 0.1123, 'sad': 0.0941, 'surprise': 0.1071, 'fear': 0.1376, 'disgust': 0.1065, 'anger': 0.1258, 'contempt': 0.1487}
# =============================================
# Emotion label for bordered_crazy_good_frame_121_border.png: surprise
# {'neutral': 0.1383, 'happy': 0.1406, 'sad': 0.1066, 'surprise': 0.1545, 'fear': 0.1526, 'disgust': 0.1116, 'anger': 0.078, 'contempt': 0.1177}
# =============================================
# Invalid input for bordered_crazy_good_frame_120_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_116_border.png: neutral
# {'neutral': 0.3223, 'happy': 0.1434, 'sad': 0.092, 'surprise': 0.0837, 'fear': 0.0673, 'disgust': 0.0605, 'anger': 0.1416, 'contempt': 0.0892}
# =============================================
# Invalid input for bordered_crazy_good_frame_115_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_114_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_11_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_119_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_113_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_112_border.png: sad
# {'neutral': 0.2544, 'happy': 0.0172, 'sad': 0.555, 'surprise': 0.0589, 'fear': 0.0296, 'disgust': 0.0142, 'anger': 0.0462, 'contempt': 0.0245}
# =============================================
# Invalid input for bordered_crazy_good_frame_111_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_110_border.png: sad
# {'neutral': 0.0714, 'happy': 0.0154, 'sad': 0.7906, 'surprise': 0.0409, 'fear': 0.0395, 'disgust': 0.0134, 'anger': 0.0137, 'contempt': 0.0152}
# =============================================
# Invalid input for bordered_crazy_good_frame_117_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_118_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_10_border.png: sad
# {'neutral': 0.2517, 'happy': 0.0864, 'sad': 0.2536, 'surprise': 0.0962, 'fear': 0.0804, 'disgust': 0.0416, 'anger': 0.1009, 'contempt': 0.0893}
# =============================================
# Emotion label for bordered_crazy_good_frame_109_border.png: sad
# {'neutral': 0.1721, 'happy': 0.03, 'sad': 0.3718, 'surprise': 0.2539, 'fear': 0.0997, 'disgust': 0.017, 'anger': 0.0321, 'contempt': 0.0234}
# =============================================
# Invalid input for bordered_crazy_good_frame_108_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_101_border.png: happy
# {'neutral': 0.2938, 'happy': 0.3105, 'sad': 0.0402, 'surprise': 0.0893, 'fear': 0.0576, 'disgust': 0.0313, 'anger': 0.0602, 'contempt': 0.1171}
# =============================================
# Emotion label for bordered_crazy_good_frame_107_border.png: anger
# {'neutral': 0.0683, 'happy': 0.2331, 'sad': 0.1831, 'surprise': 0.0561, 'fear': 0.0983, 'disgust': 0.0415, 'anger': 0.2921, 'contempt': 0.0274}
# =============================================
# Invalid input for bordered_crazy_good_frame_106_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_100_border.png: sad
# {'neutral': 0.1327, 'happy': 0.0333, 'sad': 0.6978, 'surprise': 0.0583, 'fear': 0.0398, 'disgust': 0.0111, 'anger': 0.0208, 'contempt': 0.0061}
# =============================================
# Emotion label for bordered_crazy_good_frame_0_border.png: sad
# {'neutral': 0.054, 'happy': 0.0338, 'sad': 0.6889, 'surprise': 0.0409, 'fear': 0.0361, 'disgust': 0.0052, 'anger': 0.1365, 'contempt': 0.0045}
# =============================================
# Invalid input for bordered_crazy_good_frame_105_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_104_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_103_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_102_border.png: neutral
# {'neutral': 0.3899, 'happy': 0.0993, 'sad': 0.1026, 'surprise': 0.0763, 'fear': 0.0732, 'disgust': 0.0504, 'anger': 0.1335, 'contempt': 0.0749}
# =============================================
# Emotion label for bordered_crazy_good_frame_175_border.png: anger
# {'neutral': 0.0458, 'happy': 0.0307, 'sad': 0.0241, 'surprise': 0.0198, 'fear': 0.0295, 'disgust': 0.1132, 'anger': 0.664, 'contempt': 0.073}
# =============================================
# Emotion label for bordered_crazy_good_frame_174_border.png: anger
# {'neutral': 0.0561, 'happy': 0.0391, 'sad': 0.0268, 'surprise': 0.0261, 'fear': 0.0321, 'disgust': 0.1663, 'anger': 0.5293, 'contempt': 0.1243}
# =============================================
# Emotion label for bordered_crazy_good_frame_173_border.png: fear
# {'neutral': 0.1108, 'happy': 0.0281, 'sad': 0.0447, 'surprise': 0.2253, 'fear': 0.3869, 'disgust': 0.014, 'anger': 0.1216, 'contempt': 0.0686}
# =============================================
# Emotion label for bordered_crazy_good_frame_172_border.png: fear
# {'neutral': 0.1482, 'happy': 0.0304, 'sad': 0.0753, 'surprise': 0.2166, 'fear': 0.2632, 'disgust': 0.0113, 'anger': 0.1282, 'contempt': 0.1268}
# =============================================
# Emotion label for bordered_crazy_good_frame_171_border.png: fear
# {'neutral': 0.0732, 'happy': 0.0259, 'sad': 0.0422, 'surprise': 0.348, 'fear': 0.3916, 'disgust': 0.0139, 'anger': 0.0584, 'contempt': 0.0469}
# =============================================
# Emotion label for bordered_crazy_good_frame_170_border.png: surprise
# {'neutral': 0.0427, 'happy': 0.0273, 'sad': 0.015, 'surprise': 0.6405, 'fear': 0.187, 'disgust': 0.0228, 'anger': 0.0523, 'contempt': 0.0123}
# =============================================
# Invalid input for bordered_crazy_good_frame_16_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_169_border.png: fear
# {'neutral': 0.014, 'happy': 0.02, 'sad': 0.0281, 'surprise': 0.4416, 'fear': 0.4487, 'disgust': 0.0143, 'anger': 0.0134, 'contempt': 0.0199}
# =============================================
# Emotion label for bordered_crazy_good_frame_160_border.png: neutral
# {'neutral': 0.2522, 'happy': 0.1914, 'sad': 0.0687, 'surprise': 0.1624, 'fear': 0.0978, 'disgust': 0.0471, 'anger': 0.0928, 'contempt': 0.0877}
# =============================================
# Invalid input for bordered_crazy_good_frame_15_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_154_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_153_border.png: surprise
# {'neutral': 0.168, 'happy': 0.1086, 'sad': 0.0794, 'surprise': 0.1907, 'fear': 0.1425, 'disgust': 0.1088, 'anger': 0.0862, 'contempt': 0.1159}
# =============================================
# Emotion label for bordered_crazy_good_frame_152_border.png: happy
# {'neutral': 0.1423, 'happy': 0.2111, 'sad': 0.1653, 'surprise': 0.1455, 'fear': 0.1338, 'disgust': 0.0464, 'anger': 0.0858, 'contempt': 0.07}
# =============================================
# Emotion label for bordered_crazy_good_frame_159_border.png: neutral
# {'neutral': 0.3461, 'happy': 0.1343, 'sad': 0.0979, 'surprise': 0.0851, 'fear': 0.0897, 'disgust': 0.043, 'anger': 0.1275, 'contempt': 0.0764}
# =============================================
# Emotion label for bordered_crazy_good_frame_158_border.png: surprise
# {'neutral': 0.179, 'happy': 0.0932, 'sad': 0.1044, 'surprise': 0.1998, 'fear': 0.1486, 'disgust': 0.0799, 'anger': 0.0979, 'contempt': 0.0973}
# =============================================
# Invalid input for bordered_crazy_good_frame_157_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_151_border.png: sad
# {'neutral': 0.0899, 'happy': 0.0422, 'sad': 0.4528, 'surprise': 0.1944, 'fear': 0.1016, 'disgust': 0.0489, 'anger': 0.0446, 'contempt': 0.0255}
# =============================================
# Emotion label for bordered_crazy_good_frame_150_border.png: sad
# {'neutral': 0.0676, 'happy': 0.0456, 'sad': 0.5433, 'surprise': 0.057, 'fear': 0.0938, 'disgust': 0.0387, 'anger': 0.1327, 'contempt': 0.0214}
# =============================================
# Invalid input for bordered_crazy_good_frame_14_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_148_border.png: sad
# {'neutral': 0.1521, 'happy': 0.1067, 'sad': 0.257, 'surprise': 0.0507, 'fear': 0.1113, 'disgust': 0.0927, 'anger': 0.1864, 'contempt': 0.0431}
# =============================================
# Invalid input for bordered_crazy_good_frame_156_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_155_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_149_border.png: neutral
# {'neutral': 0.2234, 'happy': 0.1819, 'sad': 0.161, 'surprise': 0.0747, 'fear': 0.0753, 'disgust': 0.0579, 'anger': 0.118, 'contempt': 0.1078}
# =============================================
# Emotion label for bordered_crazy_good_frame_147_border.png: sad
# {'neutral': 0.1163, 'happy': 0.0652, 'sad': 0.4673, 'surprise': 0.0503, 'fear': 0.1449, 'disgust': 0.0494, 'anger': 0.0785, 'contempt': 0.0281}
# =============================================
# Emotion label for bordered_crazy_good_frame_146_border.png: anger
# {'neutral': 0.2018, 'happy': 0.1196, 'sad': 0.1943, 'surprise': 0.0567, 'fear': 0.098, 'disgust': 0.0593, 'anger': 0.2138, 'contempt': 0.0565}
# =============================================
# Emotion label for bordered_crazy_good_frame_141_border.png: anger
# {'neutral': 0.0747, 'happy': 0.0827, 'sad': 0.1294, 'surprise': 0.0365, 'fear': 0.0394, 'disgust': 0.1676, 'anger': 0.4419, 'contempt': 0.0278}
# =============================================
# Emotion label for bordered_crazy_good_frame_140_border.png: sad
# {'neutral': 0.1175, 'happy': 0.0515, 'sad': 0.447, 'surprise': 0.1821, 'fear': 0.0997, 'disgust': 0.0321, 'anger': 0.0385, 'contempt': 0.0315}
# =============================================
# Emotion label for bordered_crazy_good_frame_145_border.png: anger
# {'neutral': 0.0618, 'happy': 0.0884, 'sad': 0.0856, 'surprise': 0.0472, 'fear': 0.1811, 'disgust': 0.0373, 'anger': 0.4624, 'contempt': 0.0362}
# =============================================
# Emotion label for bordered_crazy_good_frame_144_border.png: fear
# {'neutral': 0.0574, 'happy': 0.0907, 'sad': 0.0863, 'surprise': 0.0689, 'fear': 0.3266, 'disgust': 0.0199, 'anger': 0.3097, 'contempt': 0.0404}
# =============================================
# Invalid input for bordered_crazy_good_frame_13_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_139_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_138_border.png: neutral
# {'neutral': 0.2998, 'happy': 0.1093, 'sad': 0.096, 'surprise': 0.0803, 'fear': 0.0773, 'disgust': 0.0683, 'anger': 0.1664, 'contempt': 0.1027}
# =============================================
# Emotion label for bordered_crazy_good_frame_137_border.png: happy
# {'neutral': 0.1387, 'happy': 0.2492, 'sad': 0.082, 'surprise': 0.078, 'fear': 0.0843, 'disgust': 0.0882, 'anger': 0.1139, 'contempt': 0.1658}
# =============================================
# Emotion label for bordered_crazy_good_frame_135_border.png: surprise
# {'neutral': 0.1237, 'happy': 0.0191, 'sad': 0.1955, 'surprise': 0.4516, 'fear': 0.1434, 'disgust': 0.0106, 'anger': 0.0386, 'contempt': 0.0176}
# =============================================
# Invalid input for bordered_crazy_good_frame_143_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_142_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_136_border.png: anger
# {'neutral': 0.0981, 'happy': 0.1125, 'sad': 0.1295, 'surprise': 0.0756, 'fear': 0.1616, 'disgust': 0.0817, 'anger': 0.2537, 'contempt': 0.0873}
# =============================================
# Emotion label for bordered_crazy_good_frame_133_border.png: surprise
# {'neutral': 0.102, 'happy': 0.0337, 'sad': 0.2274, 'surprise': 0.3969, 'fear': 0.1647, 'disgust': 0.0194, 'anger': 0.0395, 'contempt': 0.0164}
# =============================================
# Emotion label for bordered_crazy_good_frame_134_border.png: surprise
# {'neutral': 0.1398, 'happy': 0.0237, 'sad': 0.255, 'surprise': 0.4254, 'fear': 0.0596, 'disgust': 0.0174, 'anger': 0.0492, 'contempt': 0.03}
# =============================================
# Invalid input for bordered_crazy_good_frame_128_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_129_border.png: sad
# {'neutral': 0.0668, 'happy': 0.0203, 'sad': 0.6146, 'surprise': 0.0783, 'fear': 0.096, 'disgust': 0.0316, 'anger': 0.0704, 'contempt': 0.0221}
# =============================================
# Emotion label for bordered_crazy_good_frame_131_border.png: surprise
# {'neutral': 0.1305, 'happy': 0.0165, 'sad': 0.2532, 'surprise': 0.4341, 'fear': 0.0971, 'disgust': 0.0103, 'anger': 0.0387, 'contempt': 0.0196}
# =============================================
# Emotion label for bordered_crazy_good_frame_132_border.png: sad
# {'neutral': 0.1662, 'happy': 0.0185, 'sad': 0.3678, 'surprise': 0.3089, 'fear': 0.0581, 'disgust': 0.0125, 'anger': 0.0482, 'contempt': 0.0198}
# =============================================
# Emotion label for bordered_crazy_good_frame_127_border.png: sad
# {'neutral': 0.0862, 'happy': 0.0373, 'sad': 0.5158, 'surprise': 0.1497, 'fear': 0.1219, 'disgust': 0.0254, 'anger': 0.0407, 'contempt': 0.0228}
# =============================================
# Invalid input for bordered_crazy_good_frame_126_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_125_border.png: anger
# {'neutral': 0.1509, 'happy': 0.111, 'sad': 0.1082, 'surprise': 0.0856, 'fear': 0.1303, 'disgust': 0.1207, 'anger': 0.1575, 'contempt': 0.1357}
# =============================================
# Invalid input for bordered_crazy_good_frame_124_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_123_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_130_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_12_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_231_border.png: anger
# {'neutral': 0.0559, 'happy': 0.0254, 'sad': 0.1156, 'surprise': 0.1103, 'fear': 0.3169, 'disgust': 0.0391, 'anger': 0.3274, 'contempt': 0.0095}
# =============================================
# Emotion label for bordered_crazy_good_frame_230_border.png: anger
# {'neutral': 0.0204, 'happy': 0.0343, 'sad': 0.0182, 'surprise': 0.0265, 'fear': 0.0599, 'disgust': 0.1055, 'anger': 0.7117, 'contempt': 0.0235}
# =============================================
# Emotion label for bordered_crazy_good_frame_223_border.png: anger
# {'neutral': 0.1553, 'happy': 0.0655, 'sad': 0.1627, 'surprise': 0.0784, 'fear': 0.1079, 'disgust': 0.069, 'anger': 0.3054, 'contempt': 0.0556}
# =============================================
# Emotion label for bordered_crazy_good_frame_222_border.png: disgust
# {'neutral': 0.037, 'happy': 0.0371, 'sad': 0.0318, 'surprise': 0.0204, 'fear': 0.059, 'disgust': 0.5779, 'anger': 0.1761, 'contempt': 0.0607}
# =============================================
# Emotion label for bordered_crazy_good_frame_221_border.png: fear
# {'neutral': 0.0264, 'happy': 0.0308, 'sad': 0.073, 'surprise': 0.0811, 'fear': 0.6502, 'disgust': 0.0598, 'anger': 0.0616, 'contempt': 0.0171}
# =============================================
# Emotion label for bordered_crazy_good_frame_215_border.png: anger
# {'neutral': 0.183, 'happy': 0.0415, 'sad': 0.0712, 'surprise': 0.0607, 'fear': 0.0675, 'disgust': 0.0578, 'anger': 0.3145, 'contempt': 0.2037}
# =============================================
# Emotion label for bordered_crazy_good_frame_214_border.png: anger
# {'neutral': 0.111, 'happy': 0.0333, 'sad': 0.0482, 'surprise': 0.0378, 'fear': 0.0416, 'disgust': 0.0351, 'anger': 0.5744, 'contempt': 0.1186}
# =============================================
# Emotion label for bordered_crazy_good_frame_220_border.png: neutral
# {'neutral': 0.3215, 'happy': 0.0334, 'sad': 0.2233, 'surprise': 0.1684, 'fear': 0.1, 'disgust': 0.0216, 'anger': 0.0918, 'contempt': 0.0401}
# =============================================
# Invalid input for bordered_crazy_good_frame_21_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_213_border.png: anger
# {'neutral': 0.1433, 'happy': 0.0353, 'sad': 0.036, 'surprise': 0.0345, 'fear': 0.0407, 'disgust': 0.0409, 'anger': 0.4939, 'contempt': 0.1754}
# =============================================
# Emotion label for bordered_crazy_good_frame_212_border.png: anger
# {'neutral': 0.1084, 'happy': 0.051, 'sad': 0.0489, 'surprise': 0.0376, 'fear': 0.0405, 'disgust': 0.0593, 'anger': 0.4108, 'contempt': 0.2437}
# =============================================
# Emotion label for bordered_crazy_good_frame_211_border.png: fear
# {'neutral': 0.0217, 'happy': 0.0268, 'sad': 0.057, 'surprise': 0.2159, 'fear': 0.6242, 'disgust': 0.0152, 'anger': 0.0202, 'contempt': 0.0189}
# =============================================
# Emotion label for bordered_crazy_good_frame_210_border.png: surprise
# {'neutral': 0.0492, 'happy': 0.018, 'sad': 0.064, 'surprise': 0.6586, 'fear': 0.1486, 'disgust': 0.0073, 'anger': 0.0233, 'contempt': 0.031}
# =============================================
# Invalid input for bordered_crazy_good_frame_20_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_219_border.png: sad
# {'neutral': 0.025, 'happy': 0.0349, 'sad': 0.4219, 'surprise': 0.0483, 'fear': 0.0803, 'disgust': 0.0692, 'anger': 0.2874, 'contempt': 0.0331}
# =============================================
# Emotion label for bordered_crazy_good_frame_218_border.png: sad
# {'neutral': 0.0216, 'happy': 0.0377, 'sad': 0.4895, 'surprise': 0.0484, 'fear': 0.1166, 'disgust': 0.0586, 'anger': 0.1906, 'contempt': 0.0372}
# =============================================
# Emotion label for bordered_crazy_good_frame_217_border.png: sad
# {'neutral': 0.0215, 'happy': 0.0364, 'sad': 0.4729, 'surprise': 0.0457, 'fear': 0.0813, 'disgust': 0.0697, 'anger': 0.2478, 'contempt': 0.0247}
# =============================================
# Emotion label for bordered_crazy_good_frame_216_border.png: anger
# {'neutral': 0.2275, 'happy': 0.0364, 'sad': 0.0924, 'surprise': 0.0376, 'fear': 0.0373, 'disgust': 0.0305, 'anger': 0.3919, 'contempt': 0.1464}
# =============================================
# Emotion label for bordered_crazy_good_frame_209_border.png: surprise
# {'neutral': 0.0712, 'happy': 0.0237, 'sad': 0.1865, 'surprise': 0.4324, 'fear': 0.2041, 'disgust': 0.0382, 'anger': 0.0212, 'contempt': 0.0226}
# =============================================
# Emotion label for bordered_crazy_good_frame_208_border.png: fear
# {'neutral': 0.052, 'happy': 0.0315, 'sad': 0.1218, 'surprise': 0.141, 'fear': 0.4194, 'disgust': 0.1118, 'anger': 0.0779, 'contempt': 0.0446}
# =============================================
# Emotion label for bordered_crazy_good_frame_207_border.png: fear
# {'neutral': 0.0587, 'happy': 0.0293, 'sad': 0.1372, 'surprise': 0.1839, 'fear': 0.3762, 'disgust': 0.0861, 'anger': 0.0727, 'contempt': 0.0559}
# =============================================
# Emotion label for bordered_crazy_good_frame_202_border.png: sad
# {'neutral': 0.1601, 'happy': 0.0166, 'sad': 0.5559, 'surprise': 0.0385, 'fear': 0.053, 'disgust': 0.0124, 'anger': 0.1341, 'contempt': 0.0295}
# =============================================
# Emotion label for bordered_crazy_good_frame_201_border.png: neutral
# {'neutral': 0.4091, 'happy': 0.0409, 'sad': 0.1705, 'surprise': 0.0325, 'fear': 0.022, 'disgust': 0.012, 'anger': 0.1473, 'contempt': 0.1657}
# =============================================
# Emotion label for bordered_crazy_good_frame_200_border.png: surprise
# {'neutral': 0.0495, 'happy': 0.021, 'sad': 0.0255, 'surprise': 0.4702, 'fear': 0.3416, 'disgust': 0.0158, 'anger': 0.0428, 'contempt': 0.0335}
# =============================================
# Emotion label for bordered_crazy_good_frame_206_border.png: sad
# {'neutral': 0.2251, 'happy': 0.033, 'sad': 0.3498, 'surprise': 0.0245, 'fear': 0.036, 'disgust': 0.0158, 'anger': 0.166, 'contempt': 0.1498}
# =============================================
# Emotion label for bordered_crazy_good_frame_205_border.png: neutral
# {'neutral': 0.282, 'happy': 0.0298, 'sad': 0.2776, 'surprise': 0.0233, 'fear': 0.0312, 'disgust': 0.0134, 'anger': 0.245, 'contempt': 0.0978}
# =============================================
# Invalid input for bordered_crazy_good_frame_1_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_19_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_199_border.png: surprise
# {'neutral': 0.055, 'happy': 0.0261, 'sad': 0.025, 'surprise': 0.5883, 'fear': 0.1931, 'disgust': 0.0227, 'anger': 0.0613, 'contempt': 0.0286}
# =============================================
# Emotion label for bordered_crazy_good_frame_198_border.png: sad
# {'neutral': 0.1188, 'happy': 0.0221, 'sad': 0.6461, 'surprise': 0.0337, 'fear': 0.0206, 'disgust': 0.022, 'anger': 0.0673, 'contempt': 0.0696}
# =============================================
# Emotion label for bordered_crazy_good_frame_204_border.png: anger
# {'neutral': 0.148, 'happy': 0.0413, 'sad': 0.0999, 'surprise': 0.0251, 'fear': 0.0265, 'disgust': 0.0569, 'anger': 0.5165, 'contempt': 0.0858}
# =============================================
# Emotion label for bordered_crazy_good_frame_203_border.png: sad
# {'neutral': 0.2391, 'happy': 0.0299, 'sad': 0.2941, 'surprise': 0.0393, 'fear': 0.0465, 'disgust': 0.0219, 'anger': 0.2173, 'contempt': 0.1118}
# =============================================
# Emotion label for bordered_crazy_good_frame_197_border.png: sad
# {'neutral': 0.3, 'happy': 0.0227, 'sad': 0.3161, 'surprise': 0.046, 'fear': 0.03, 'disgust': 0.0144, 'anger': 0.2048, 'contempt': 0.0659}
# =============================================
# Emotion label for bordered_crazy_good_frame_196_border.png: sad
# {'neutral': 0.3181, 'happy': 0.0257, 'sad': 0.4168, 'surprise': 0.049, 'fear': 0.0399, 'disgust': 0.0099, 'anger': 0.0959, 'contempt': 0.0446}
# =============================================
# Emotion label for bordered_crazy_good_frame_195_border.png: anger
# {'neutral': 0.3036, 'happy': 0.0898, 'sad': 0.1004, 'surprise': 0.054, 'fear': 0.0451, 'disgust': 0.0653, 'anger': 0.3153, 'contempt': 0.0264}
# =============================================
# Emotion label for bordered_crazy_good_frame_189_border.png: fear
# {'neutral': 0.029, 'happy': 0.023, 'sad': 0.033, 'surprise': 0.2984, 'fear': 0.5259, 'disgust': 0.0444, 'anger': 0.0267, 'contempt': 0.0196}
# =============================================
# Emotion label for bordered_crazy_good_frame_188_border.png: surprise
# {'neutral': 0.0527, 'happy': 0.0215, 'sad': 0.023, 'surprise': 0.5526, 'fear': 0.2553, 'disgust': 0.0146, 'anger': 0.0341, 'contempt': 0.0462}
# =============================================
# Emotion label for bordered_crazy_good_frame_194_border.png: anger
# {'neutral': 0.263, 'happy': 0.0431, 'sad': 0.0867, 'surprise': 0.0428, 'fear': 0.0383, 'disgust': 0.0532, 'anger': 0.4547, 'contempt': 0.0184}
# =============================================
# Emotion label for bordered_crazy_good_frame_193_border.png: neutral
# {'neutral': 0.3809, 'happy': 0.0894, 'sad': 0.1009, 'surprise': 0.064, 'fear': 0.0584, 'disgust': 0.0656, 'anger': 0.1926, 'contempt': 0.0483}
# =============================================
# Emotion label for bordered_crazy_good_frame_187_border.png: surprise
# {'neutral': 0.154, 'happy': 0.0402, 'sad': 0.0299, 'surprise': 0.5336, 'fear': 0.0252, 'disgust': 0.023, 'anger': 0.1245, 'contempt': 0.0696}
# =============================================
# Emotion label for bordered_crazy_good_frame_185_border.png: surprise
# {'neutral': 0.103, 'happy': 0.0372, 'sad': 0.1935, 'surprise': 0.3396, 'fear': 0.1312, 'disgust': 0.0234, 'anger': 0.1461, 'contempt': 0.0259}
# =============================================
# Emotion label for bordered_crazy_good_frame_186_border.png: surprise
# {'neutral': 0.09, 'happy': 0.0276, 'sad': 0.0714, 'surprise': 0.6071, 'fear': 0.0717, 'disgust': 0.0515, 'anger': 0.0595, 'contempt': 0.0214}
# =============================================
# Emotion label for bordered_crazy_good_frame_183_border.png: contempt
# {'neutral': 0.306, 'happy': 0.089, 'sad': 0.0423, 'surprise': 0.1053, 'fear': 0.0577, 'disgust': 0.0443, 'anger': 0.0481, 'contempt': 0.3072}
# =============================================
# Emotion label for bordered_crazy_good_frame_184_border.png: surprise
# {'neutral': 0.1325, 'happy': 0.0273, 'sad': 0.151, 'surprise': 0.2821, 'fear': 0.2021, 'disgust': 0.0376, 'anger': 0.1268, 'contempt': 0.0406}
# =============================================
# Emotion label for bordered_crazy_good_frame_192_border.png: neutral
# {'neutral': 0.3373, 'happy': 0.0913, 'sad': 0.106, 'surprise': 0.0658, 'fear': 0.0611, 'disgust': 0.0778, 'anger': 0.2205, 'contempt': 0.0402}
# =============================================
# Emotion label for bordered_crazy_good_frame_191_border.png: neutral
# {'neutral': 0.3072, 'happy': 0.0723, 'sad': 0.0933, 'surprise': 0.0898, 'fear': 0.0678, 'disgust': 0.0863, 'anger': 0.2493, 'contempt': 0.034}
# =============================================
# Emotion label for bordered_crazy_good_frame_190_border.png: neutral
# {'neutral': 0.3419, 'happy': 0.1353, 'sad': 0.094, 'surprise': 0.0627, 'fear': 0.0494, 'disgust': 0.0814, 'anger': 0.1621, 'contempt': 0.0732}
# =============================================
# Emotion label for bordered_crazy_good_frame_18_border.png: anger
# {'neutral': 0.1051, 'happy': 0.1128, 'sad': 0.1046, 'surprise': 0.0992, 'fear': 0.0789, 'disgust': 0.0976, 'anger': 0.288, 'contempt': 0.1138}
# =============================================
# Emotion label for bordered_crazy_good_frame_182_border.png: surprise
# {'neutral': 0.2606, 'happy': 0.0387, 'sad': 0.0747, 'surprise': 0.2753, 'fear': 0.1581, 'disgust': 0.0204, 'anger': 0.1167, 'contempt': 0.0554}
# =============================================
# Emotion label for bordered_crazy_good_frame_181_border.png: neutral
# {'neutral': 0.3745, 'happy': 0.0441, 'sad': 0.0926, 'surprise': 0.1733, 'fear': 0.0645, 'disgust': 0.0345, 'anger': 0.1304, 'contempt': 0.0861}
# =============================================
# Emotion label for bordered_crazy_good_frame_180_border.png: neutral
# {'neutral': 0.2796, 'happy': 0.044, 'sad': 0.2493, 'surprise': 0.0515, 'fear': 0.0556, 'disgust': 0.0354, 'anger': 0.1735, 'contempt': 0.111}
# =============================================
# Emotion label for bordered_crazy_good_frame_168_border.png: surprise
# {'neutral': 0.0172, 'happy': 0.0176, 'sad': 0.0208, 'surprise': 0.6388, 'fear': 0.2445, 'disgust': 0.0136, 'anger': 0.0294, 'contempt': 0.0183}
# =============================================
# Emotion label for bordered_crazy_good_frame_167_border.png: surprise
# {'neutral': 0.0159, 'happy': 0.0181, 'sad': 0.0206, 'surprise': 0.5465, 'fear': 0.3357, 'disgust': 0.0162, 'anger': 0.0333, 'contempt': 0.0137}
# =============================================
# Emotion label for bordered_crazy_good_frame_166_border.png: fear
# {'neutral': 0.02, 'happy': 0.0216, 'sad': 0.0203, 'surprise': 0.3429, 'fear': 0.5131, 'disgust': 0.0258, 'anger': 0.0321, 'contempt': 0.0241}
# =============================================
# Emotion label for bordered_crazy_good_frame_165_border.png: surprise
# {'neutral': 0.0414, 'happy': 0.0216, 'sad': 0.0162, 'surprise': 0.657, 'fear': 0.1812, 'disgust': 0.0126, 'anger': 0.043, 'contempt': 0.027}
# =============================================
# Emotion label for bordered_crazy_good_frame_164_border.png: surprise
# {'neutral': 0.1314, 'happy': 0.109, 'sad': 0.0821, 'surprise': 0.2224, 'fear': 0.185, 'disgust': 0.0839, 'anger': 0.0938, 'contempt': 0.0924}
# =============================================
# Invalid input for bordered_crazy_good_frame_163_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_162_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_17_border.png: anger
# {'neutral': 0.1297, 'happy': 0.1113, 'sad': 0.145, 'surprise': 0.1019, 'fear': 0.0968, 'disgust': 0.1219, 'anger': 0.1787, 'contempt': 0.1147}
# =============================================
# Emotion label for bordered_crazy_good_frame_179_border.png: sad
# {'neutral': 0.1588, 'happy': 0.1218, 'sad': 0.2112, 'surprise': 0.0791, 'fear': 0.0703, 'disgust': 0.0449, 'anger': 0.1539, 'contempt': 0.1601}
# =============================================
# Emotion label for bordered_crazy_good_frame_178_border.png: neutral
# {'neutral': 0.3175, 'happy': 0.0388, 'sad': 0.2934, 'surprise': 0.0272, 'fear': 0.0329, 'disgust': 0.015, 'anger': 0.0934, 'contempt': 0.1819}
# =============================================
# Emotion label for bordered_crazy_good_frame_177_border.png: neutral
# {'neutral': 0.3035, 'happy': 0.0491, 'sad': 0.2392, 'surprise': 0.0714, 'fear': 0.0573, 'disgust': 0.0363, 'anger': 0.1428, 'contempt': 0.1004}
# =============================================
# Invalid input for bordered_crazy_good_frame_161_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_176_border.png: anger
# {'neutral': 0.0308, 'happy': 0.0245, 'sad': 0.0179, 'surprise': 0.0158, 'fear': 0.022, 'disgust': 0.0594, 'anger': 0.7912, 'contempt': 0.0384}
# =============================================
# Invalid input for bordered_crazy_good_frame_288_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_283_border.png: sad
# {'neutral': 0.0388, 'happy': 0.0265, 'sad': 0.6019, 'surprise': 0.028, 'fear': 0.1705, 'disgust': 0.0176, 'anger': 0.0568, 'contempt': 0.0599}
# =============================================
# Emotion label for bordered_crazy_good_frame_282_border.png: contempt
# {'neutral': 0.115, 'happy': 0.1319, 'sad': 0.0851, 'surprise': 0.1296, 'fear': 0.1472, 'disgust': 0.1245, 'anger': 0.0901, 'contempt': 0.1767}
# =============================================
# Emotion label for bordered_crazy_good_frame_281_border.png: contempt
# {'neutral': 0.1143, 'happy': 0.1389, 'sad': 0.0776, 'surprise': 0.1262, 'fear': 0.1248, 'disgust': 0.1329, 'anger': 0.0925, 'contempt': 0.1928}
# =============================================
# Invalid input for bordered_crazy_good_frame_287_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_286_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_280_border.png: anger
# {'neutral': 0.0815, 'happy': 0.0313, 'sad': 0.1158, 'surprise': 0.0775, 'fear': 0.1144, 'disgust': 0.1167, 'anger': 0.4258, 'contempt': 0.037}
# =============================================
# Invalid input for bordered_crazy_good_frame_27_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_279_border.png: anger
# {'neutral': 0.0684, 'happy': 0.0283, 'sad': 0.0778, 'surprise': 0.0815, 'fear': 0.0976, 'disgust': 0.1292, 'anger': 0.4773, 'contempt': 0.0399}
# =============================================
# Emotion label for bordered_crazy_good_frame_278_border.png: anger
# {'neutral': 0.0931, 'happy': 0.0315, 'sad': 0.1309, 'surprise': 0.0662, 'fear': 0.1235, 'disgust': 0.0511, 'anger': 0.4748, 'contempt': 0.0289}
# =============================================
# Emotion label for bordered_crazy_good_frame_285_border.png: sad
# {'neutral': 0.0494, 'happy': 0.0263, 'sad': 0.5679, 'surprise': 0.0307, 'fear': 0.1437, 'disgust': 0.0179, 'anger': 0.0991, 'contempt': 0.0651}
# =============================================
# Emotion label for bordered_crazy_good_frame_284_border.png: sad
# {'neutral': 0.0376, 'happy': 0.0285, 'sad': 0.5267, 'surprise': 0.0366, 'fear': 0.2322, 'disgust': 0.0146, 'anger': 0.0584, 'contempt': 0.0653}
# =============================================
# Emotion label for bordered_crazy_good_frame_277_border.png: sad
# {'neutral': 0.1675, 'happy': 0.0288, 'sad': 0.5485, 'surprise': 0.0435, 'fear': 0.0235, 'disgust': 0.0125, 'anger': 0.1412, 'contempt': 0.0345}
# =============================================
# Invalid input for bordered_crazy_good_frame_276_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_275_border.png: surprise
# {'neutral': 0.0905, 'happy': 0.0963, 'sad': 0.0938, 'surprise': 0.253, 'fear': 0.1812, 'disgust': 0.1533, 'anger': 0.0657, 'contempt': 0.0664}
# =============================================
# Invalid input for bordered_crazy_good_frame_270_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_26_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_269_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_268_border.png: fear
# {'neutral': 0.0143, 'happy': 0.0455, 'sad': 0.0254, 'surprise': 0.2585, 'fear': 0.3323, 'disgust': 0.2046, 'anger': 0.0919, 'contempt': 0.0274}
# =============================================
# Emotion label for bordered_crazy_good_frame_267_border.png: fear
# {'neutral': 0.0224, 'happy': 0.0179, 'sad': 0.0371, 'surprise': 0.2356, 'fear': 0.4167, 'disgust': 0.183, 'anger': 0.0666, 'contempt': 0.0206}
# =============================================
# Emotion label for bordered_crazy_good_frame_266_border.png: disgust
# {'neutral': 0.0132, 'happy': 0.0185, 'sad': 0.0451, 'surprise': 0.0189, 'fear': 0.108, 'disgust': 0.7113, 'anger': 0.0793, 'contempt': 0.0057}
# =============================================
# Emotion label for bordered_crazy_good_frame_265_border.png: anger
# {'neutral': 0.0287, 'happy': 0.2691, 'sad': 0.1858, 'surprise': 0.0275, 'fear': 0.0678, 'disgust': 0.0283, 'anger': 0.3817, 'contempt': 0.0112}
# =============================================
# Emotion label for bordered_crazy_good_frame_274_border.png: fear
# {'neutral': 0.123, 'happy': 0.1079, 'sad': 0.0978, 'surprise': 0.1296, 'fear': 0.193, 'disgust': 0.1079, 'anger': 0.106, 'contempt': 0.1349}
# =============================================
# Emotion label for bordered_crazy_good_frame_273_border.png: surprise
# {'neutral': 0.0175, 'happy': 0.0693, 'sad': 0.034, 'surprise': 0.3531, 'fear': 0.2138, 'disgust': 0.2039, 'anger': 0.0472, 'contempt': 0.0612}
# =============================================
# Invalid input for bordered_crazy_good_frame_272_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_271_border.png: disgust
# {'neutral': 0.0232, 'happy': 0.0228, 'sad': 0.0359, 'surprise': 0.0244, 'fear': 0.1077, 'disgust': 0.6963, 'anger': 0.0656, 'contempt': 0.024}
# =============================================
# Emotion label for bordered_crazy_good_frame_264_border.png: anger
# {'neutral': 0.0335, 'happy': 0.2121, 'sad': 0.0741, 'surprise': 0.0222, 'fear': 0.1567, 'disgust': 0.1495, 'anger': 0.34, 'contempt': 0.0119}
# =============================================
# Emotion label for bordered_crazy_good_frame_263_border.png: disgust
# {'neutral': 0.0103, 'happy': 0.0204, 'sad': 0.015, 'surprise': 0.0166, 'fear': 0.0439, 'disgust': 0.788, 'anger': 0.0859, 'contempt': 0.0199}
# =============================================
# Emotion label for bordered_crazy_good_frame_262_border.png: disgust
# {'neutral': 0.0202, 'happy': 0.0248, 'sad': 0.036, 'surprise': 0.0235, 'fear': 0.0463, 'disgust': 0.7795, 'anger': 0.0433, 'contempt': 0.0264}
# =============================================
# Emotion label for bordered_crazy_good_frame_257_border.png: fear
# {'neutral': 0.0589, 'happy': 0.0276, 'sad': 0.1041, 'surprise': 0.1612, 'fear': 0.5307, 'disgust': 0.0259, 'anger': 0.058, 'contempt': 0.0337}
# =============================================
# Emotion label for bordered_crazy_good_frame_256_border.png: disgust
# {'neutral': 0.0224, 'happy': 0.0186, 'sad': 0.0522, 'surprise': 0.0192, 'fear': 0.0501, 'disgust': 0.764, 'anger': 0.05, 'contempt': 0.0236}
# =============================================
# Emotion label for bordered_crazy_good_frame_261_border.png: disgust
# {'neutral': 0.0211, 'happy': 0.0297, 'sad': 0.0826, 'surprise': 0.0352, 'fear': 0.2618, 'disgust': 0.4986, 'anger': 0.0337, 'contempt': 0.0374}
# =============================================
# Invalid input for bordered_crazy_good_frame_260_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_255_border.png: disgust
# {'neutral': 0.0223, 'happy': 0.0317, 'sad': 0.1047, 'surprise': 0.0285, 'fear': 0.0686, 'disgust': 0.5823, 'anger': 0.1353, 'contempt': 0.0266}
# =============================================
# Emotion label for bordered_crazy_good_frame_254_border.png: disgust
# {'neutral': 0.0195, 'happy': 0.0348, 'sad': 0.0871, 'surprise': 0.0438, 'fear': 0.1752, 'disgust': 0.5238, 'anger': 0.0915, 'contempt': 0.0243}
# =============================================
# Emotion label for bordered_crazy_good_frame_253_border.png: sad
# {'neutral': 0.033, 'happy': 0.0478, 'sad': 0.7473, 'surprise': 0.0347, 'fear': 0.0685, 'disgust': 0.0123, 'anger': 0.0173, 'contempt': 0.0392}
# =============================================
# Emotion label for bordered_crazy_good_frame_252_border.png: sad
# {'neutral': 0.0809, 'happy': 0.0578, 'sad': 0.3636, 'surprise': 0.0395, 'fear': 0.1075, 'disgust': 0.0675, 'anger': 0.2481, 'contempt': 0.035}
# =============================================
# Invalid input for bordered_crazy_good_frame_251_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_25_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_259_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_258_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_250_border.png: disgust
# {'neutral': 0.0112, 'happy': 0.0196, 'sad': 0.0214, 'surprise': 0.0159, 'fear': 0.0416, 'disgust': 0.8383, 'anger': 0.0366, 'contempt': 0.0152}
# =============================================
# Invalid input for bordered_crazy_good_frame_24_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_249_border.png: disgust
# {'neutral': 0.0103, 'happy': 0.0163, 'sad': 0.0152, 'surprise': 0.0144, 'fear': 0.0387, 'disgust': 0.8539, 'anger': 0.036, 'contempt': 0.0152}
# =============================================
# Emotion label for bordered_crazy_good_frame_248_border.png: disgust
# {'neutral': 0.0208, 'happy': 0.0252, 'sad': 0.0338, 'surprise': 0.0252, 'fear': 0.1341, 'disgust': 0.6683, 'anger': 0.0593, 'contempt': 0.0333}
# =============================================
# Invalid input for bordered_crazy_good_frame_242_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_241_border.png: anger
# {'neutral': 0.0329, 'happy': 0.0362, 'sad': 0.0314, 'surprise': 0.0328, 'fear': 0.1964, 'disgust': 0.1018, 'anger': 0.5365, 'contempt': 0.032}
# =============================================
# Emotion label for bordered_crazy_good_frame_240_border.png: fear
# {'neutral': 0.0533, 'happy': 0.0331, 'sad': 0.1024, 'surprise': 0.0763, 'fear': 0.5866, 'disgust': 0.0399, 'anger': 0.0778, 'contempt': 0.0305}
# =============================================
# Emotion label for bordered_crazy_good_frame_247_border.png: disgust
# {'neutral': 0.0157, 'happy': 0.0215, 'sad': 0.0261, 'surprise': 0.0219, 'fear': 0.0893, 'disgust': 0.745, 'anger': 0.0552, 'contempt': 0.0254}
# =============================================
# Emotion label for bordered_crazy_good_frame_246_border.png: disgust
# {'neutral': 0.0214, 'happy': 0.0235, 'sad': 0.0315, 'surprise': 0.0256, 'fear': 0.1342, 'disgust': 0.6744, 'anger': 0.0505, 'contempt': 0.039}
# =============================================
# Invalid input for bordered_crazy_good_frame_245_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_23_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_239_border.png: disgust
# {'neutral': 0.0518, 'happy': 0.0445, 'sad': 0.1071, 'surprise': 0.0355, 'fear': 0.1051, 'disgust': 0.3569, 'anger': 0.2561, 'contempt': 0.043}
# =============================================
# Invalid input for bordered_crazy_good_frame_238_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_237_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_244_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_243_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_236_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_235_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_234_border.png: contempt
# {'neutral': 0.1295, 'happy': 0.1212, 'sad': 0.0842, 'surprise': 0.1221, 'fear': 0.14, 'disgust': 0.1323, 'anger': 0.0988, 'contempt': 0.1718}
# =============================================
# Invalid input for bordered_crazy_good_frame_22_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_229_border.png: contempt
# {'neutral': 0.1224, 'happy': 0.1479, 'sad': 0.0963, 'surprise': 0.1154, 'fear': 0.1174, 'disgust': 0.116, 'anger': 0.0925, 'contempt': 0.192}
# =============================================
# Emotion label for bordered_crazy_good_frame_228_border.png: anger
# {'neutral': 0.1313, 'happy': 0.0559, 'sad': 0.0791, 'surprise': 0.0437, 'fear': 0.0612, 'disgust': 0.0678, 'anger': 0.5017, 'contempt': 0.0593}
# =============================================
# Invalid input for bordered_crazy_good_frame_233_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_232_border.png: neutral
# {'neutral': 0.226, 'happy': 0.1722, 'sad': 0.1403, 'surprise': 0.0725, 'fear': 0.094, 'disgust': 0.0287, 'anger': 0.0788, 'contempt': 0.1874}
# =============================================
# Invalid input for bordered_crazy_good_frame_227_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_226_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_225_border.png: anger
# {'neutral': 0.017, 'happy': 0.0274, 'sad': 0.0143, 'surprise': 0.0258, 'fear': 0.0424, 'disgust': 0.013, 'anger': 0.8414, 'contempt': 0.0187}
# =============================================
# Emotion label for bordered_crazy_good_frame_224_border.png: anger
# {'neutral': 0.1031, 'happy': 0.0811, 'sad': 0.1277, 'surprise': 0.0705, 'fear': 0.1437, 'disgust': 0.0957, 'anger': 0.291, 'contempt': 0.0872}
# =============================================
# Emotion label for bordered_crazy_good_frame_342_border.png: neutral
# {'neutral': 0.1905, 'happy': 0.1226, 'sad': 0.1164, 'surprise': 0.1184, 'fear': 0.1167, 'disgust': 0.1052, 'anger': 0.106, 'contempt': 0.1243}
# =============================================
# Emotion label for bordered_crazy_good_frame_337_border.png: disgust
# {'neutral': 0.1399, 'happy': 0.1093, 'sad': 0.0867, 'surprise': 0.1135, 'fear': 0.1436, 'disgust': 0.1828, 'anger': 0.1234, 'contempt': 0.1009}
# =============================================
# Emotion label for bordered_crazy_good_frame_336_border.png: disgust
# {'neutral': 0.162, 'happy': 0.1524, 'sad': 0.0811, 'surprise': 0.0926, 'fear': 0.1209, 'disgust': 0.1747, 'anger': 0.1396, 'contempt': 0.0767}
# =============================================
# Emotion label for bordered_crazy_good_frame_335_border.png: neutral
# {'neutral': 0.1932, 'happy': 0.0956, 'sad': 0.0749, 'surprise': 0.1591, 'fear': 0.1213, 'disgust': 0.1203, 'anger': 0.0724, 'contempt': 0.1632}
# =============================================
# Emotion label for bordered_crazy_good_frame_341_border.png: disgust
# {'neutral': 0.154, 'happy': 0.1551, 'sad': 0.0813, 'surprise': 0.0764, 'fear': 0.1013, 'disgust': 0.1828, 'anger': 0.0878, 'contempt': 0.1613}
# =============================================
# Emotion label for bordered_crazy_good_frame_340_border.png: contempt
# {'neutral': 0.1372, 'happy': 0.122, 'sad': 0.0852, 'surprise': 0.1084, 'fear': 0.1306, 'disgust': 0.142, 'anger': 0.1092, 'contempt': 0.1654}
# =============================================
# Emotion label for bordered_crazy_good_frame_334_border.png: surprise
# {'neutral': 0.04, 'happy': 0.0325, 'sad': 0.1299, 'surprise': 0.4, 'fear': 0.2742, 'disgust': 0.0383, 'anger': 0.0498, 'contempt': 0.0354}
# =============================================
# Emotion label for bordered_crazy_good_frame_333_border.png: fear
# {'neutral': 0.0411, 'happy': 0.0294, 'sad': 0.0939, 'surprise': 0.0389, 'fear': 0.6591, 'disgust': 0.0439, 'anger': 0.0721, 'contempt': 0.0216}
# =============================================
# Emotion label for bordered_crazy_good_frame_332_border.png: fear
# {'neutral': 0.0488, 'happy': 0.0301, 'sad': 0.1167, 'surprise': 0.0495, 'fear': 0.546, 'disgust': 0.0565, 'anger': 0.1225, 'contempt': 0.0299}
# =============================================
# Emotion label for bordered_crazy_good_frame_331_border.png: sad
# {'neutral': 0.0775, 'happy': 0.0097, 'sad': 0.7688, 'surprise': 0.039, 'fear': 0.0231, 'disgust': 0.0032, 'anger': 0.0657, 'contempt': 0.013}
# =============================================
# Invalid input for bordered_crazy_good_frame_33_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_339_border.png: happy
# {'neutral': 0.1549, 'happy': 0.1831, 'sad': 0.0811, 'surprise': 0.1105, 'fear': 0.0928, 'disgust': 0.1331, 'anger': 0.1412, 'contempt': 0.1032}
# =============================================
# Emotion label for bordered_crazy_good_frame_338_border.png: neutral
# {'neutral': 0.2143, 'happy': 0.1146, 'sad': 0.1112, 'surprise': 0.1053, 'fear': 0.0957, 'disgust': 0.0982, 'anger': 0.1229, 'contempt': 0.1378}
# =============================================
# Emotion label for bordered_crazy_good_frame_330_border.png: sad
# {'neutral': 0.1051, 'happy': 0.0117, 'sad': 0.6309, 'surprise': 0.0395, 'fear': 0.0363, 'disgust': 0.0046, 'anger': 0.1471, 'contempt': 0.0247}
# =============================================
# Invalid input for bordered_crazy_good_frame_32_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_329_border.png: sad
# {'neutral': 0.2016, 'happy': 0.0202, 'sad': 0.3487, 'surprise': 0.0629, 'fear': 0.0568, 'disgust': 0.0658, 'anger': 0.2102, 'contempt': 0.0336}
# =============================================
# Emotion label for bordered_crazy_good_frame_322_border.png: sad
# {'neutral': 0.1646, 'happy': 0.0273, 'sad': 0.4287, 'surprise': 0.0722, 'fear': 0.0717, 'disgust': 0.0441, 'anger': 0.1657, 'contempt': 0.0256}
# =============================================
# Emotion label for bordered_crazy_good_frame_328_border.png: sad
# {'neutral': 0.1705, 'happy': 0.0263, 'sad': 0.3951, 'surprise': 0.0602, 'fear': 0.0542, 'disgust': 0.0811, 'anger': 0.1859, 'contempt': 0.0268}
# =============================================
# Invalid input for bordered_crazy_good_frame_327_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_321_border.png: sad
# ...
# =============================================
# Emotion label for bordered_crazy_good_frame_64_border.png: anger
# {'neutral': 0.1109, 'happy': 0.0153, 'sad': 0.0931, 'surprise': 0.1812, 'fear': 0.0747, 'disgust': 0.0161, 'anger': 0.4916, 'contempt': 0.0172}
# =============================================
# Invalid input for bordered_crazy_good_frame_71_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_70_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_63_border.png: surprise
# {'neutral': 0.0838, 'happy': 0.018, 'sad': 0.0861, 'surprise': 0.4321, 'fear': 0.1306, 'disgust': 0.0217, 'anger': 0.2147, 'contempt': 0.013}
# =============================================
# Emotion label for bordered_crazy_good_frame_62_border.png: fear
# {'neutral': 0.1426, 'happy': 0.0722, 'sad': 0.1368, 'surprise': 0.191, 'fear': 0.271, 'disgust': 0.065, 'anger': 0.0507, 'contempt': 0.0707}
# =============================================
# Emotion label for bordered_crazy_good_frame_61_border.png: surprise
# {'neutral': 0.0876, 'happy': 0.0162, 'sad': 0.1207, 'surprise': 0.603, 'fear': 0.0989, 'disgust': 0.0108, 'anger': 0.0529, 'contempt': 0.01}
# =============================================
# Emotion label for bordered_crazy_good_frame_57_border.png: fear
# {'neutral': 0.0356, 'happy': 0.0249, 'sad': 0.2664, 'surprise': 0.1647, 'fear': 0.456, 'disgust': 0.0163, 'anger': 0.0252, 'contempt': 0.011}
# =============================================
# Emotion label for bordered_crazy_good_frame_56_border.png: fear
# {'neutral': 0.0256, 'happy': 0.0244, 'sad': 0.2837, 'surprise': 0.1005, 'fear': 0.5123, 'disgust': 0.0221, 'anger': 0.0216, 'contempt': 0.0098}
# =============================================
# Emotion label for bordered_crazy_good_frame_55_border.png: sad
# {'neutral': 0.0472, 'happy': 0.0246, 'sad': 0.4982, 'surprise': 0.1436, 'fear': 0.2289, 'disgust': 0.0246, 'anger': 0.0235, 'contempt': 0.0093}
# =============================================
# Emotion label for bordered_crazy_good_frame_60_border.png: surprise
# {'neutral': 0.142, 'happy': 0.024, 'sad': 0.1528, 'surprise': 0.3536, 'fear': 0.1488, 'disgust': 0.0203, 'anger': 0.1442, 'contempt': 0.0143}
# =============================================
# Invalid input for bordered_crazy_good_frame_5_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_54_border.png: surprise
# {'neutral': 0.0359, 'happy': 0.0233, 'sad': 0.1056, 'surprise': 0.4173, 'fear': 0.378, 'disgust': 0.0109, 'anger': 0.0193, 'contempt': 0.0097}
# =============================================
# Invalid input for bordered_crazy_good_frame_53_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_52_border.png: sad
# {'neutral': 0.0682, 'happy': 0.0127, 'sad': 0.7846, 'surprise': 0.0417, 'fear': 0.0123, 'disgust': 0.01, 'anger': 0.0654, 'contempt': 0.0051}
# =============================================
# Emotion label for bordered_crazy_good_frame_51_border.png: anger
# {'neutral': 0.0771, 'happy': 0.0261, 'sad': 0.0744, 'surprise': 0.15, 'fear': 0.0243, 'disgust': 0.046, 'anger': 0.4644, 'contempt': 0.1377}
# =============================================
# Emotion label for bordered_crazy_good_frame_59_border.png: sad
# {'neutral': 0.1698, 'happy': 0.0216, 'sad': 0.2742, 'surprise': 0.2594, 'fear': 0.1137, 'disgust': 0.0146, 'anger': 0.138, 'contempt': 0.0086}
# =============================================
# Emotion label for bordered_crazy_good_frame_58_border.png: sad
# {'neutral': 0.1249, 'happy': 0.027, 'sad': 0.2952, 'surprise': 0.2642, 'fear': 0.1876, 'disgust': 0.0159, 'anger': 0.0652, 'contempt': 0.0198}
# =============================================
# Emotion label for bordered_crazy_good_frame_50_border.png: surprise
# {'neutral': 0.0621, 'happy': 0.0185, 'sad': 0.1355, 'surprise': 0.3314, 'fear': 0.021, 'disgust': 0.0724, 'anger': 0.1441, 'contempt': 0.2148}
# =============================================
# Invalid input for bordered_crazy_good_frame_4_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_49_border.png: surprise
# {'neutral': 0.0383, 'happy': 0.0237, 'sad': 0.0511, 'surprise': 0.5244, 'fear': 0.0106, 'disgust': 0.1001, 'anger': 0.043, 'contempt': 0.2088}
# =============================================
# Emotion label for bordered_crazy_good_frame_479_border.png: happy
# {'neutral': 0.068, 'happy': 0.6159, 'sad': 0.0383, 'surprise': 0.0641, 'fear': 0.0255, 'disgust': 0.0279, 'anger': 0.1248, 'contempt': 0.0355}
# =============================================
# Invalid input for bordered_crazy_good_frame_478_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_477_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_48_border.png: sad
# {'neutral': 0.1678, 'happy': 0.0285, 'sad': 0.4161, 'surprise': 0.2294, 'fear': 0.0376, 'disgust': 0.0097, 'anger': 0.0903, 'contempt': 0.0207}
# =============================================
# Invalid input for bordered_crazy_good_frame_481_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_476_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_475_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_474_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_473_border.png: surprise
# {'neutral': 0.0874, 'happy': 0.0243, 'sad': 0.1746, 'surprise': 0.3524, 'fear': 0.173, 'disgust': 0.064, 'anger': 0.0343, 'contempt': 0.0899}
# =============================================
# Invalid input for bordered_crazy_good_frame_480_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_47_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_472_border.png: surprise
# {'neutral': 0.0572, 'happy': 0.0284, 'sad': 0.193, 'surprise': 0.341, 'fear': 0.2281, 'disgust': 0.0431, 'anger': 0.0949, 'contempt': 0.0143}
# =============================================
# Invalid input for bordered_crazy_good_frame_471_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_470_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_466_border.png: surprise
# {'neutral': 0.1528, 'happy': 0.1107, 'sad': 0.1054, 'surprise': 0.1822, 'fear': 0.1665, 'disgust': 0.0775, 'anger': 0.0697, 'contempt': 0.1351}
# =============================================
# Emotion label for bordered_crazy_good_frame_465_border.png: surprise
# {'neutral': 0.1438, 'happy': 0.095, 'sad': 0.1087, 'surprise': 0.1537, 'fear': 0.1336, 'disgust': 0.1078, 'anger': 0.1272, 'contempt': 0.1301}
# =============================================
# Emotion label for bordered_crazy_good_frame_464_border.png: fear
# {'neutral': 0.1665, 'happy': 0.0925, 'sad': 0.1371, 'surprise': 0.1342, 'fear': 0.1785, 'disgust': 0.0882, 'anger': 0.1321, 'contempt': 0.0708}
# =============================================
# Invalid input for bordered_crazy_good_frame_463_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_462_border.png: sad
# {'neutral': 0.0903, 'happy': 0.0262, 'sad': 0.462, 'surprise': 0.1105, 'fear': 0.0505, 'disgust': 0.0649, 'anger': 0.1148, 'contempt': 0.0807}
# =============================================
# Emotion label for bordered_crazy_good_frame_46_border.png: neutral
# {'neutral': 0.2025, 'happy': 0.1272, 'sad': 0.0823, 'surprise': 0.1332, 'fear': 0.0915, 'disgust': 0.1047, 'anger': 0.0881, 'contempt': 0.1706}
# =============================================
# Emotion label for bordered_crazy_good_frame_469_border.png: sad
# {'neutral': 0.1195, 'happy': 0.0313, 'sad': 0.3776, 'surprise': 0.1905, 'fear': 0.1154, 'disgust': 0.0425, 'anger': 0.0625, 'contempt': 0.0607}
# =============================================
# Emotion label for bordered_crazy_good_frame_461_border.png: surprise
# {'neutral': 0.1172, 'happy': 0.0225, 'sad': 0.2489, 'surprise': 0.3096, 'fear': 0.1099, 'disgust': 0.0713, 'anger': 0.0629, 'contempt': 0.0577}
# =============================================
# Emotion label for bordered_crazy_good_frame_460_border.png: sad
# {'neutral': 0.127, 'happy': 0.0231, 'sad': 0.3694, 'surprise': 0.232, 'fear': 0.0702, 'disgust': 0.0452, 'anger': 0.0874, 'contempt': 0.0457}
# =============================================
# Emotion label for bordered_crazy_good_frame_468_border.png: sad
# {'neutral': 0.0541, 'happy': 0.0207, 'sad': 0.5889, 'surprise': 0.0945, 'fear': 0.0728, 'disgust': 0.0707, 'anger': 0.0433, 'contempt': 0.055}
# =============================================
# Emotion label for bordered_crazy_good_frame_467_border.png: sad
# {'neutral': 0.0824, 'happy': 0.0198, 'sad': 0.6476, 'surprise': 0.0594, 'fear': 0.0276, 'disgust': 0.0256, 'anger': 0.0422, 'contempt': 0.0953}
# =============================================
# Invalid input for bordered_crazy_good_frame_45_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_459_border.png: sad
# {'neutral': 0.0863, 'happy': 0.0185, 'sad': 0.3678, 'surprise': 0.241, 'fear': 0.1147, 'disgust': 0.0595, 'anger': 0.0852, 'contempt': 0.0271}
# =============================================
# Emotion label for bordered_crazy_good_frame_458_border.png: sad
# {'neutral': 0.0916, 'happy': 0.0188, 'sad': 0.3412, 'surprise': 0.2621, 'fear': 0.1338, 'disgust': 0.0645, 'anger': 0.067, 'contempt': 0.021}
# =============================================
# Emotion label for bordered_crazy_good_frame_452_border.png: sad
# {'neutral': 0.091, 'happy': 0.0183, 'sad': 0.5409, 'surprise': 0.1393, 'fear': 0.0551, 'disgust': 0.0441, 'anger': 0.0902, 'contempt': 0.021}
# =============================================
# Emotion label for bordered_crazy_good_frame_453_border.png: sad
# {'neutral': 0.1251, 'happy': 0.0188, 'sad': 0.4633, 'surprise': 0.1162, 'fear': 0.0457, 'disgust': 0.0686, 'anger': 0.1278, 'contempt': 0.0345}
# =============================================
# Emotion label for bordered_crazy_good_frame_451_border.png: sad
# {'neutral': 0.1095, 'happy': 0.0194, 'sad': 0.4529, 'surprise': 0.1608, 'fear': 0.0918, 'disgust': 0.0205, 'anger': 0.118, 'contempt': 0.027}
# =============================================
# Emotion label for bordered_crazy_good_frame_450_border.png: sad
# {'neutral': 0.1102, 'happy': 0.0169, 'sad': 0.3976, 'surprise': 0.2256, 'fear': 0.119, 'disgust': 0.0244, 'anger': 0.0831, 'contempt': 0.0232}
# =============================================
# Emotion label for bordered_crazy_good_frame_44_border.png: anger
# {'neutral': 0.1004, 'happy': 0.0371, 'sad': 0.1821, 'surprise': 0.0357, 'fear': 0.0336, 'disgust': 0.0118, 'anger': 0.5364, 'contempt': 0.0629}
# =============================================
# Emotion label for bordered_crazy_good_frame_457_border.png: sad
# {'neutral': 0.1146, 'happy': 0.0171, 'sad': 0.4495, 'surprise': 0.1709, 'fear': 0.0729, 'disgust': 0.0304, 'anger': 0.1202, 'contempt': 0.0244}
# =============================================
# Emotion label for bordered_crazy_good_frame_456_border.png: sad
# {'neutral': 0.0968, 'happy': 0.0193, 'sad': 0.5916, 'surprise': 0.1112, 'fear': 0.0459, 'disgust': 0.0436, 'anger': 0.0642, 'contempt': 0.0273}
# =============================================
# Emotion label for bordered_crazy_good_frame_97_border.png: neutral
# {'neutral': 0.245, 'happy': 0.1116, 'sad': 0.1083, 'surprise': 0.1139, 'fear': 0.1439, 'disgust': 0.0534, 'anger': 0.1606, 'contempt': 0.0632}
# =============================================
# Invalid input for bordered_crazy_good_frame_9_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_96_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_95_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_94_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_93_border.png: sad
# {'neutral': 0.0573, 'happy': 0.0328, 'sad': 0.5072, 'surprise': 0.0285, 'fear': 0.0556, 'disgust': 0.2268, 'anger': 0.0816, 'contempt': 0.0101}
# =============================================
# Emotion label for bordered_crazy_good_frame_92_border.png: neutral
# {'neutral': 0.3075, 'happy': 0.06, 'sad': 0.0983, 'surprise': 0.1266, 'fear': 0.1274, 'disgust': 0.0588, 'anger': 0.1651, 'contempt': 0.0563}
# =============================================
# Invalid input for bordered_crazy_good_frame_91_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_99_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_98_border.png: surprise
# {'neutral': 0.0986, 'happy': 0.0279, 'sad': 0.285, 'surprise': 0.3155, 'fear': 0.1294, 'disgust': 0.0222, 'anger': 0.0909, 'contempt': 0.0305}
# =============================================
# Invalid input for bordered_crazy_good_frame_90_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_8_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_89_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_83_border.png: contempt
# {'neutral': 0.1498, 'happy': 0.1404, 'sad': 0.0869, 'surprise': 0.1106, 'fear': 0.1145, 'disgust': 0.1306, 'anger': 0.1001, 'contempt': 0.167}
# =============================================
# Emotion label for bordered_crazy_good_frame_84_border.png: sad
# {'neutral': 0.0453, 'happy': 0.0362, 'sad': 0.4411, 'surprise': 0.0311, 'fear': 0.0813, 'disgust': 0.0954, 'anger': 0.2351, 'contempt': 0.0346}
# =============================================
# Invalid input for bordered_crazy_good_frame_82_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_87_border.png: anger
# {'neutral': 0.0217, 'happy': 0.027, 'sad': 0.3285, 'surprise': 0.0219, 'fear': 0.04, 'disgust': 0.1143, 'anger': 0.4271, 'contempt': 0.0196}
# =============================================
# Emotion label for bordered_crazy_good_frame_88_border.png: sad
# {'neutral': 0.024, 'happy': 0.0319, 'sad': 0.5093, 'surprise': 0.0345, 'fear': 0.064, 'disgust': 0.0843, 'anger': 0.2184, 'contempt': 0.0335}
# =============================================
# Invalid input for bordered_crazy_good_frame_81_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_80_border.png: sad
# {'neutral': 0.0691, 'happy': 0.0354, 'sad': 0.601, 'surprise': 0.0267, 'fear': 0.0388, 'disgust': 0.0808, 'anger': 0.0453, 'contempt': 0.103}
# =============================================
# Emotion label for bordered_crazy_good_frame_7_border.png: sad
# {'neutral': 0.0993, 'happy': 0.0777, 'sad': 0.2248, 'surprise': 0.1384, 'fear': 0.1998, 'disgust': 0.073, 'anger': 0.1583, 'contempt': 0.0288}
# =============================================
# Invalid input for bordered_crazy_good_frame_78_border.png
# =============================================
# Emotion label for bordered_crazy_good_frame_86_border.png: contempt
# {'neutral': 0.1592, 'happy': 0.157, 'sad': 0.2156, 'surprise': 0.0833, 'fear': 0.0185, 'disgust': 0.0284, 'anger': 0.0286, 'contempt': 0.3094}
# =============================================
# Invalid input for bordered_crazy_good_frame_85_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_79_border.png
# =============================================
# Invalid input for bordered_crazy_good_frame_77_border.png
# =============================================
#
# Found 167 invalid picture(s) out of 482 (34.65%)
# CPU times: user 2min 21s, sys: 2.06 s, total: 2min 23s
# Wall time: 3min 1s

# %%
sum_dict = defaultdict(int)

for emotion in ('neutral', 'happy', 'sad', 'surprise', 'fear', 'disgust', 'anger', 'contempt'):
    sum_dict[emotion] = sum(1 for _ in os.scandir(os.path.join(path_to_save, emotion)))

sum_dict
# Out:
# defaultdict(int,
#             {'anger': 334,
#              'contempt': 89,
#              'disgust': 234,
#              'fear': 321,
#              'happy': 417,
#              'neutral': 225,
#              'sad': 602,
#              'surprise': 318})

# %%
mean_vals = dict(zip(dic.keys(), list(map(lambda x : np.mean(x), dic.values()))))
(dic, mean_vals)
